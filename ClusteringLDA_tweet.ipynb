# %% [markdown]
# # **Clustering y LDA**![lda.png](data:image/png;base64,...)

# %%
#upload
install.packages("tm")
install.packages("NLP")
install.packages("slam")
install.packages("qdap")
library(tm)
library(qdap)
require(openNLP)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘slam’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘openNLPdata’, ‘rJava’, ‘bitops’, ‘plyr’, ‘qdapDictionaries’, ‘qdapRegex’, ‘qdapTools’, ‘chron’, ‘gender’, ‘gridExtra’, ‘igraph’, ‘openNLP’, ‘openxlsx’, ‘plotrix’, ‘RCurl’, ‘reshape2’, ‘stringdist’, ‘venneuler’, ‘wordcloud’, ‘XML’
#
#
# Loading required package: NLP
#
# Loading required package: qdapDictionaries
#
# Loading required package: qdapRegex
#
# Loading required package: qdapTools
#
# Loading required package: RColorBrewer
#
#
# Attaching package: ‘qdap’
#
#
# The following objects are masked from ‘package:tm’:
#
# ...

# %% [markdown]
# # Lectura del Directorio

# %%
#Lectura del directorio
install.packages("openNLP")
c <- Corpus(DirSource("/content/nuevo"))
summary(c)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#                                    Length Class             Mode
# #AsumeTuVotoIdiota.txt             2      PlainTextDocument list
# #CuartoPoder.txt                   2      PlainTextDocument list
# #PuntoFinal.txt                    2      PlainTextDocument list
# #VacanciaPedroCastillo.txt         2      PlainTextDocument list
# #VigilaTuKarpaIdiota.txt           2      PlainTextDocument list
# Adriana Tudela.txt                 2      PlainTextDocument list
# APRA.txt                           2      PlainTextDocument list
# AUGUST TREMBLES FOR LISA.txt       2      PlainTextDocument list
# Barcos.txt                         2      PlainTextDocument list
# Bellido.txt                        2      PlainTextDocument list
# Benítez.txt                        2      PlainTextDocument list
# Binacional.txt                     2      PlainTextDocument list
# ...

# %%
wordcloud(words = c, min.freq = 1, max.words=200, random.order=FALSE, rot.per=0.35,colors=brewer.pal(8, "Dark2"))
# Out:
# plot without title

# %%
#convertir a una matriz
dtm <- DocumentTermMatrix(c)
x<-as.matrix(dtm)
rownames(x) <- paste(substring(rownames(x),1,4))
x
#distancia
m <- as.matrix(dist(x))
d <- as.dist(m)
stopifnot(d == dist(x))

#Clustering
# Out:
#      abimael abril abrimos abuela acabará acabó acertado acomplejado
# #Asu  16     3     2        1     2       1     1        1
# #Cua   0     0     0        0     0       2     0        0
# #Pun   0     0     0        0     0       0     0        0
# #Vac   3     0     0        0     0       0     1        0
# #Vig   0     0     0        0     0       0     0        0
# Adri   3     0     0        3     0       0     0        1
# APRA   2     0     0        0     0       1     0        0
# AUGU   0     0     0        0     0       0     0        0
# Barc   1     0     0        1     0       2     0        0
# Bell  21     0     0        0     0       0     0        0
# Bení   0     0     0        0     0       0     0        0
# Bina   0     0     0        0     0       0     0        0
# Breñ   0     0     0        0     0       0     0        0
# BTS    0     0     0        0     0       0     0        0
# Bust   0     1     0        0     0       5     0        0
# ...

# %%
library(cluster)
#Segun el numero de clusters, podrian ser 3 pero nuestros datos no son tan similares entonces escogi el segundo codo
#buscar el numero de clusters
m.scaled<-scale(x)
k.max <- 15
data <- m.scaled
sil <- rep(0, k.max)
# Iterar con K=2 a 15
# k = 2 to k = 5
for(i in 2:k.max){
  km.res <- kmeans(data, centers = i, nstart = 25, iter.max=30)#https://stat.ethz.ch/pipermail/r-help/2006-March/102752.html
  ss <- silhouette(km.res$cluster, dist(data))
  sil[i] <- mean(ss[, 3])
}

# Plot the  average silhouette width
plot(1:k.max, sil, type = "b", pch = 19, 
     frame = FALSE, xlab = "Number of clusters k")
abline(v = which.max(sil), lty = 2)
# Out:
# plot without title

# %%
#dendogram
groups <- hclust(d,method="ward.D")
plot(groups, hang=-1)
rect.hclust(groups,2)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
#clustering
#k means algorithm, 2 clusters, 100 starting configurations
kfit <- kmeans(d, 2, nstart=100)
#plot â€“ need library cluster

clusplot(m, kfit$cluster, color=T, shade=T, labels=2, lines=0)
# Out:
# Plot with title “CLUSPLOT( m )”

# %%
library(cluster)
#clustering
#k means algorithm, 2 clusters, 100 starting configurations
kfit <- kmeans(d, 6, nstart=100)
#plot â€“ need library cluster

clusplot(m, kfit$cluster, color=T, shade=T, labels=2, lines=0)
# Out:
# Plot with title “CLUSPLOT( m )”

# %%
#clustering
#k means algorithm, 2 clusters, 100 starting configurations
kfit <- kmeans(d, 12, nstart=100)
#plot â€“ need library cluster

clusplot(m, kfit$cluster, color=T, shade=T, labels=2, lines=0)
# Out:
# Plot with title “CLUSPLOT( m )”

# %% [markdown]
# # **LDA**
# Mostramos 3 csvs con :
#
#
# *   topicos de los documentos,
# *   Los top 10 terminos oir cada topico
# *   Las probailidades de asociacion con cada topico

# %%
#install.packages('topicmodels', repos='http://cran.rstudio.com/')


system2('sudo', 'apt-get install libgsl0-dev')
install.packages("topicmodels")
library("topicmodels")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘modeltools’

# %%
#Set parameters for Gibbs sampling
burnin <- 4000
iter <- 2000
thin <- 500
seed <-list(2003,5,63,100001,765)
nstart <- 5
best <- TRUE

#Number of topics
k <- 10


#Run LDA using Gibbs sampling
ldaOut <-LDA(dtm,k, method="Gibbs", control=list(nstart=nstart, seed = seed, best=best, burnin = burnin, iter = iter, thin=thin))


#write out results
#docs to topics
ldaOut.topics <- as.matrix(topics(ldaOut))
write.csv(ldaOut.topics,file=paste("LDAGibbs",k,"DocsToTopics.csv"))


#top 10 terms in each topic
ldaOut.terms <- as.matrix(terms(ldaOut,10))
write.csv(ldaOut.terms,file=paste("LDAGibbs",k,"TopicsToTerms.csv"))

#probabilities associated with each topic assignment
topicProbabilities <- as.data.frame(ldaOut@gamma)
write.csv(topicProbabilities,file=paste("LDAGibbs",k,"TopicProbabilities.csv"))
print("FINISH")
# Out:
# [1] "FINISH"

# %%
install.packages("wordcloud")
library(wordcloud)
install.packages("RColorBrewer")
library(RColorBrewer)
install.packages("wordcloud2")
library("wordcloud2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘htmlwidgets’

# %%
(ldaOut.terms)
# Out:
#       Topic 1        Topic 2     Topic 3  Topic 4 Topic 5    Topic 6
#  [1,] vote           castillo    castillo simon   gabriel    bellido
#  [2,] bts            canal       soto     grupos  costa      salazar
#  [3,] bomba          jorge       hernando team    binacional hamilton
#  [4,] pop            marcha      palacio  barcos  francke    molinelli
#  [5,] pinks          stay        breña    mora    melgar     gabinete
#  [6,] world          gobierno    pedro    bustos  valenzuela juan
#  [7,] revolutionized apra        amaru    solo    colo       sendero
#  [8,] superstar      tudela      bellido  alianza partido    abogado
#  [9,] august         adriana     gobierno matzuda presidente mrta
# [10,] trembles       anniversary peru     quiero  goles      caso
#       Topic 7       Topic 8   Topic 9  Topic 10
#  [1,] luli          mineta    run      yulimar
#  [2,] rey           lagos     bts      rojas
#  [3,] rafael        castillo  juan     venezuela
# ...
